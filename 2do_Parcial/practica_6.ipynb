# %% [markdown]
# <a href="https://colab.research.google.com/github/fgoldenboy19/Mineria-De-Datos./blob/main/2do_Parcial/practica_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Practica 6

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import numpy as np

# --- Synthetic Data Generation (Integrated to ensure file availability) ---
np.random.seed(42)

num_students = 100

asistencia = np.random.randint(50, 100, num_students)
tareas = np.random.randint(40, 95, num_students)
examen = np.random.randint(30, 90, num_students)
horas_estudio = np.random.randint(1, 15, num_students)

resultado = []
for i in range(num_students):
    score = (asistencia[i] * 0.3) + (tareas[i] * 0.3) + (examen[i] * 0.3) + (horas_estudio[i] * 0.1)
    if score > 70 and horas_estudio[i] > 5:
        resultado.append('Aprobado')
    elif score > 50 and horas_estudio[i] > 2:
        resultado.append('Reprobado')
    else:
        resultado.append('Reprobado')

synthetic_df = pd.DataFrame({
    "Asistencia": asistencia,
    "Tareas": tareas,
    "Examen": examen,
    "Horas_Estudio": horas_estudio,
    "Resultado": resultado
})

synthetic_df.to_csv("estudiantes_modelo.csv", index=False)
print("Synthetic 'estudiantes_modelo.csv' created successfully within the main cell.")
# --- End Synthetic Data Generation ---

df = pd.read_csv("estudiantes_modelo.csv")

X = df[["Asistencia", "Tareas", "Examen", "Horas_Estudio"]]
y = df["Resultado"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

modelo = DecisionTreeClassifier(random_state=42)
modelo.fit(X_train, y_train)

predicciones = modelo.predict(X_test)

exactitud = accuracy_score(y_test, predicciones)

print("Predicciones:")
print(predicciones)

print("Resultados reales:")
print(y_test.values)

print("Exactitud del modelo:")
print(exactitud)

print("Matriz de confusión:")
print(confusion_matrix(y_test, predicciones))

print("Reporte de clasificación:")
print(classification_report(y_test, predicciones))

nuevos_estudiantes = pd.DataFrame({
    "Asistencia": [95, 60, 78],
    "Tareas": [90, 55, 80],
    "Examen": [92, 50, 70],
    "Horas_Estudio": [12, 3, 7]
})

nuevas_predicciones = modelo.predict(nuevos_estudiantes)

print(nuevas_predicciones)
# Out:
# Synthetic 'estudiantes_modelo.csv' created successfully within the main cell.
# Predicciones:
# ['Reprobado' 'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado'
#  'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado'
#  'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado'
#  'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado'
#  'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado']
# Resultados reales:
# ['Reprobado' 'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado'
#  'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado'
#  'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado' 'Reprobado' 'Aprobado'
#  'Aprobado' 'Reprobado' 'Reprobado' 'Aprobado' 'Reprobado' 'Reprobado'
#  'Aprobado' 'Reprobado' 'Reprobado' 'Aprobado' 'Reprobado' 'Reprobado']
# Exactitud del modelo:
# 0.8333333333333334
# Matriz de confusión:
# [[ 0  5]
#  [ 0 25]]
# Reporte de clasificación:
# ...

# %% [markdown]
# ### Creating a Synthetic Dataset
#
# Since `estudiantes_modelo.csv` was not found, I will create a synthetic dataset for demonstration purposes. This dataset will have columns: `Asistencia`, `Tareas`, `Examen`, `Horas_Estudio`, and `Resultado`, which are expected by your model.

# %%
import numpy as np

# Generate synthetic data
np.random.seed(42)

num_students = 100

asistencia = np.random.randint(50, 100, num_students)
tareas = np.random.randint(40, 95, num_students)
examen = np.random.randint(30, 90, num_students)
horas_estudio = np.random.randint(1, 15, num_students)

# Create 'Resultado' based on a simple logic
# For example, students with higher combined scores and study hours tend to pass
resultado = []
for i in range(num_students):
    score = (asistencia[i] * 0.3) + (tareas[i] * 0.3) + (examen[i] * 0.3) + (horas_estudio[i] * 0.1)
    if score > 70 and horas_estudio[i] > 5: # Example passing criteria
        resultado.append('Aprobado')
    elif score > 50 and horas_estudio[i] > 2:
        resultado.append('Reprobado') # Simplified for demonstration
    else:
        resultado.append('Reprobado')

synthetic_df = pd.DataFrame({
    "Asistencia": asistencia,
    "Tareas": tareas,
    "Examen": examen,
    "Horas_Estudio": horas_estudio,
    "Resultado": resultado
})

synthetic_df.to_csv("estudiantes_modelo.csv", index=False)

print("Synthetic 'estudiantes_modelo.csv' created successfully.")
display(synthetic_df.head())
