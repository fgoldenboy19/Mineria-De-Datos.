# %% [markdown]
# <a href="https://colab.research.google.com/github/fgoldenboy19/Mineria-De-Datos./blob/main/2do-Parcial/Actividad_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Practica3

import pandas as pd

datos = pd.read_csv("estudiantes.csv")

correlaciones = datos.corr(numeric_only=True)
print(correlaciones)

relacion = datos["Horas_Estudio"].corr(
    datos["Calificacion_Final"])

print("Correlación horas/calificación:", relacion)



#Practica3
import pandas as pd

datos = pd.read_csv("estudiantes.csv")

# print("Matrícula:",
#       datos["Matricula"].corr(datos["Calificacion_Final"])) # This line caused the KeyError

print("Edad:",
      datos["Edad"].corr(datos["Calificacion_Final"]))

print("Asistencia:",
      datos["Asistencia"].corr(datos["Calificacion_Final"]))

print("Tareas:",
      datos["Tareas"].corr(datos["Calificacion_Final"]))

print("Examen:",
      datos["Examen"].corr(datos["Calificacion_Final"]))

print("Horas de estudio:",
      datos["Horas_Estudio"].corr(datos["Calificacion_Final"]))
# Out:
#                         Edad  Asistencia    Tareas    Examen  Horas_Estudio  \
# Edad                1.000000    0.300000  0.242536  0.400000       0.300000
# Asistencia          0.300000    1.000000  0.848875  0.900000       1.000000
# Tareas              0.242536    0.848875  1.000000  0.970143       0.848875
# Examen              0.400000    0.900000  0.970143  1.000000       0.900000
# Horas_Estudio       0.300000    1.000000  0.848875  0.900000       1.000000
# Calificacion_Final  0.335877    0.951652  0.959443  0.988971       0.951652
#
#                     Calificacion_Final
# Edad                          0.335877
# Asistencia                    0.951652
# Tareas                        0.959443
# Examen                        0.988971
# Horas_Estudio                 0.951652
# Calificacion_Final            1.000000
# Correlación horas/calificación: 0.9516515478491469
# Edad: 0.33587701688793414
# Asistencia: 0.9516515478491469
# Tareas: 0.959443008442548
# ...

# %%
import pandas as pd

datos = {
    "Edad":[20,21,22,23,24],
    "Asistencia":[90,85,95,80,100],
    "Tareas":[8,9,10,7,10],
    "Examen":[85,90,95,80,100],
    "Horas_Estudio":[5,4,6,3,7],
    "Calificacion_Final":[86,88,95,78,100]
}

pd.DataFrame(datos).to_csv("estudiantes.csv", index=False)

print("Archivo creado")
# Out:
# Archivo creado
